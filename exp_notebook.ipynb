# %%
# %matplotlib notebook

import sys
sys.path.append("./")

# %%
import os
import numpy as np
from glob import glob
from PIL import Image
from matplotlib import pyplot as plt

# %%
files = glob("output_dir/*.png")
base_dir = "/home/saad/DataDrive1/Dataset/H36M/Cropped_Data/images/valid/"

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(121)
bx = fig.add_subplot(122)
plt.ion()

for filepath in files:
    actual_filename = filepath.split("/")[1].split(".")[0]
    gt_filepath = os.path.join(base_dir, f"{actual_filename}.jpg")
    with Image.open(filepath) as pred, Image.open(gt_filepath) as gt:
        ax.imshow(gt)
        bx.imshow(pred)
        
        fig.canvas.draw()
        fig.canvas.flush_events()
        plt.pause(0.0001)
        ax.clear()
        bx.clear()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1089.9166666666667">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24367/626845699.py in <module>
#      14         bx.imshow(pred)
#      15
# ---> 16         fig.canvas.draw()
#      17         fig.canvas.flush_events()
#      18         plt.pause(0.0001)
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     151         self._png_is_old = True
#     152         try:
# --> 153             super().draw()
#     154         finally:
#     155             self.manager.refresh_all()  # Swap the frames.
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# ...
